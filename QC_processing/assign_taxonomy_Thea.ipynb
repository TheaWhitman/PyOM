# %%
# I got the latest greengenes db from the QIIME website 
# Unzipped it (tar -zxvf file.tar.gz) and put it in the Field folder
# This is the assign taxonomy command from QIIME, using the greengenes database at 97%. I am inputting the bacteria
# file of OTU sequences.
# It is using the default uclust method, at default min 0.9 similarity
# It's not working because of an issue making a file in my temporary folder directory.
# So, I just made that folder...
nprocs = 20
# !mkdir /tmp/thea_tmp
# !assign_taxonomy.py -i data/otusn.pick.fasta -t gg_13_8_otus/taxonomy/97_otu_taxonomy.txt \
-r gg_13_8_otus/rep_set/97_otus.fasta -o data/Classification/

# %%
ls data/Classification/
# Out:
# otusn.pick_tax_assignments.log  otusn.pick_tax_assignments.txt

# %%
# !less data/Classification/otusn.pick_tax_assignments.txt
# Out:
# nellales; f__Coxiellaceae; g__; s__     1.00    3
# ; f__Gemmataceae; g__; s__      1.00    3
# OTU.5689        k__Bacteria; p__OP11; c__; o__; f__; g__; s__   1.00    1
# ttsiales; f__; g__; s__ 1.00    3
# 1.00    3
# cteriales; f__; g__; s__        0.67    3
# monadales; f__Chthonomonadaceae; g__; s__       0.67    3
# ales; f__; g__; s__     1.00    3
# __; s__ 1.00    3
# ; g__; s__      1.00    3
# 1.00    3
# s; f__; g__; s__        1.00    3
# :

# %%
# Joining the classification taxonomy to the biom table
! biom add-metadata -i data/otu_table_no211.biom -o data/otu_table_tax_no211.biom \
--observation-metadata-fp data/Classification/otusn.pick_tax_assignments.txt \
--observation-header OTUID,taxonomy,confidence,numrefdbseqs --sc-separated taxonomy

# %%
! biom summarize-table -i data/otu_table_tax_no211.biom -o data/otu_table_tax_no211_summary.txt
# Out:
# Traceback (most recent call last):
#   File "/opt/anaconda/bin/pyqi", line 177, in <module>
#     optparse_main(cmd_obj, argv[1:])
#   File "/opt/anaconda/lib/python2.7/site-packages/pyqi/core/interfaces/optparse/__init__.py", line 276, in optparse_main
#     result = optparse_cmd(local_argv[1:])
#   File "/opt/anaconda/lib/python2.7/site-packages/pyqi/core/interface.py", line 42, in __call__
#     return self._output_handler(cmd_result)
#   File "/opt/anaconda/lib/python2.7/site-packages/pyqi/core/interfaces/optparse/__init__.py", line 251, in _output_handler
#     opt_value)
#   File "/opt/anaconda/lib/python2.7/site-packages/pyqi/core/interfaces/optparse/output_handler.py", line 55, in write_list_of_strings
#     raise IOError("Output path '%s' already exists." % option_value)
# IOError: Output path 'data/otu_table_tax_no211_summary.txt' already exists.
# Num samples: 119
# Num observations: 7770
# Total count: 8330249
# Table density (fraction of non-zero values): 0.415
# Table md5 (unzipped): f4eeecfe2048e6a55c2f3ab7fccb336d
#
# Counts/sample summary:
#  Min: 8830.0
#  Max: 194356.0
#  Median: 53720.000
#  Mean: 70002.092
#  Std. dev.: 43791.090
#  Sample Metadata Categories: None provided
#  Observation Metadata Categories: taxonomy; confidence; numrefdbseqs
#
# Counts/sample detail:
#  S038: 8830.0
#  S242: 13813.0
#  S039: 15038.0
#  S129: 20512.0
#  S245: 21660.0
#  S029: 23329.0
#  S021: 25060.0
#  S239: 25681.0
#  S037: 26554.0
#  S017: 26555.0
#  S014: 26968.0
#  S027: 27587.0
#  S013: 27713.0
#  S018: 28479.0
#  S243: 28671.0
#  S012: 31182.0
#  S131: 31203.0
#  S145: 31203.0
#  S042: 31996.0
#  S246: 32120.0
#  S114: 32298.0
#  S044: 32861.0
#  S016: 34523.0
#  S148: 34617.0
#  S006: 35309.0
#  S247: 35635.0
#  S036: 36097.0
#  S043: 36098.0
#  S023: 36682.0
#  S003: 36728.0
#  S033: 37283.0
#  S034: 37348.0
#  S244: 37578.0
#  S007: 37877.0
#  S233: 39284.0
#  S028: 39352.0
#  S004: 39569.0
#  S022: 39898.0
#  S137: 39955.0
#  S048: 40087.0
#  S241: 40139.0
#  S045: 40986.0
#  S146: 41880.0
#  S117: 42691.0
#  S248: 42810.0
#  S128: 45576.0
#  S041: 46249.0
#  S141: 46890.0
#  S121: 47684.0
#  S011: 47710.0
#  S024: 48814.0
#  S026: 49017.0
#  S002: 49719.0
#  S217: 50293.0
#  S231: 51393.0
#  S008: 51542.0
#  S046: 51708.0
#  S031: 52771.0
#  S102: 53477.0
#  S216: 53720.0
#  S232: 58540.0
#  S116: 58551.0
#  S237: 58807.0
#  S234: 61928.0
#  S138: 63448.0
#  S222: 65700.0
#  S112: 66290.0
#  S209: 66337.0
#  S213: 66819.0
#  S032: 67299.0
#  S109: 67615.0
#  S227: 70308.0
#  S224: 71940.0
#  S103: 73168.0
#  S236: 73434.0
#  S218: 74627.0
#  S113: 74789.0
#  S019: 77203.0
#  S223: 78864.0
#  S229: 79837.0
#  S219: 80119.0
#  S214: 80154.0
#  S124: 81038.0
#  S111: 84124.0
#  S206: 84638.0
#  S001: 86007.0
#  S238: 88192.0
#  S009: 89290.0
#  S107: 89310.0
#  S136: 90128.0
#  S047: 90848.0
#  S147: 90944.0
#  S221: 90967.0
#  S207: 92273.0
#  S108: 96114.0
#  S127: 102935.0
#  S143: 106468.0
#  S119: 107738.0
#  S144: 108677.0
#  S101: 109686.0
#  S104: 114784.0
#  S123: 115443.0
#  S228: 119662.0
#  S118: 126421.0
#  S106: 129553.0
#  S126: 133446.0
#  S208: 139063.0
#  S122: 144272.0
#  S133: 153494.0
#  S139: 154182.0
#  S132: 159371.0
#  S134: 160612.0
#  S142: 168244.0
#  S201: 171706.0
#  S226: 171724.0
#  S202: 177721.0
#  S212: 182268.0
#  S203: 190471.0
#  S204: 194356.0

# %%
from biom.parse import parse_biom_table
t = parse_biom_table(open("data/otu_table_tax_no211.biom"))

# %%
# Trying to add the mapping data too. Oh yeah but there are doubles in the map file.
! biom add-metadata -i data/otu_table_tax_no211.biom -o data/otu_table_tax_no211_meta.biom \
--sample-metadata-fp data/MapFile.txt

# %%
! biom summarize-table -i data/otu_table_tax_no211_meta.biom -o data/otu_table_tax_no211_meta_summary.txt

# %%
! cat data/otu_table_tax_no211_meta_summary.txt
# Out:
# Num samples: 119
# Num observations: 7770
# Total count: 8330249
# Table density (fraction of non-zero values): 0.415
# Table md5 (unzipped): baeb03877d709768f5f54b8114992354
#
# Counts/sample summary:
#  Min: 8830.0
#  Max: 194356.0
#  Median: 53720.000
#  Mean: 70002.092
#  Std. dev.: 43791.090
#  Sample Metadata Categories: Plants; DayAmdmt; Amdmt; ID; Day
#  Observation Metadata Categories: taxonomy; confidence; numrefdbseqs
#
# Counts/sample detail:
#  S038: 8830.0
#  S242: 13813.0
#  S039: 15038.0
#  S129: 20512.0
#  S245: 21660.0
#  S029: 23329.0
#  S021: 25060.0
#  S239: 25681.0
#  S037: 26554.0
#  S017: 26555.0
#  S014: 26968.0
#  S027: 27587.0
#  S013: 27713.0
#  S018: 28479.0
#  S243: 28671.0
#  S012: 31182.0
#  S131: 31203.0
#  S145: 31203.0
#  S042: 31996.0
#  S246: 32120.0
#  S114: 32298.0
#  S044: 32861.0
#  S016: 34523.0
#  S148: 34617.0
#  S006: 35309.0
#  S247: 35635.0
#  S036: 36097.0
#  S043: 36098.0
#  S023: 36682.0
#  S003: 36728.0
#  S033: 37283.0
#  S034: 37348.0
#  S244: 37578.0
#  S007: 37877.0
#  S233: 39284.0
#  S028: 39352.0
#  S004: 39569.0
#  S022: 39898.0
#  S137: 39955.0
#  S048: 40087.0
#  S241: 40139.0
#  S045: 40986.0
#  S146: 41880.0
#  S117: 42691.0
#  S248: 42810.0
#  S128: 45576.0
#  S041: 46249.0
#  S141: 46890.0
#  S121: 47684.0
#  S011: 47710.0
#  S024: 48814.0
#  S026: 49017.0
#  S002: 49719.0
#  S217: 50293.0
#  S231: 51393.0
#  S008: 51542.0
#  S046: 51708.0
#  S031: 52771.0
#  S102: 53477.0
#  S216: 53720.0
#  S232: 58540.0
#  S116: 58551.0
#  S237: 58807.0
#  S234: 61928.0
#  S138: 63448.0
#  S222: 65700.0
#  S112: 66290.0
#  S209: 66337.0
#  S213: 66819.0
#  S032: 67299.0
#  S109: 67615.0
#  S227: 70308.0
#  S224: 71940.0
#  S103: 73168.0
#  S236: 73434.0
#  S218: 74627.0
#  S113: 74789.0
#  S019: 77203.0
#  S223: 78864.0
#  S229: 79837.0
#  S219: 80119.0
#  S214: 80154.0
#  S124: 81038.0
#  S111: 84124.0
#  S206: 84638.0
#  S001: 86007.0
#  S238: 88192.0
#  S009: 89290.0
#  S107: 89310.0
#  S136: 90128.0
#  S047: 90848.0
#  S147: 90944.0
#  S221: 90967.0
#  S207: 92273.0
#  S108: 96114.0
#  S127: 102935.0
#  S143: 106468.0
#  S119: 107738.0
#  S144: 108677.0
#  S101: 109686.0
#  S104: 114784.0
#  S123: 115443.0
#  S228: 119662.0
#  S118: 126421.0
#  S106: 129553.0
#  S126: 133446.0
#  S208: 139063.0
#  S122: 144272.0
#  S133: 153494.0
#  S139: 154182.0
#  S132: 159371.0
#  S134: 160612.0
#  S142: 168244.0
#  S201: 171706.0
#  S226: 171724.0
#  S202: 177721.0
#  S212: 182268.0
#  S203: 190471.0
#  S204: 194356.0

# %% [markdown]
# # My final data will be as follows:
# # My OTU table
# # This has OTUs and counts per sample
# [test](data/otu_table.biom)
#
# # This file has the sequences of my OTUs
# > data/otusn.pick.fasta
#
# # This file has the assigned taxonomy of my OTUs
# > data/Classification/otusn.pick_tax_assignments.txt
#
# # The mapping file is still
# > data/MapFile.txt
#
# # I have a final .biom file with the taxonomy info in it
# > data/otu_table_tax.biom
# > data/otu_table_tax_no211.biom
#
# # These should be the only files I care about from now on.
# # Also note, I have created an aligned file
# > ssu-aln.bacteria.mask.fasta
#
# # And I have also a tree
# > ssu-aln.bacteria.mask.tre
